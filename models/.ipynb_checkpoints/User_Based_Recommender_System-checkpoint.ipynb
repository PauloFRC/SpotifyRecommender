# %% [markdown]
# # Recomendador Baseado em Similaridade de Usuários

# %%
import pandas as pd
import numpy as np
from scipy.spatial.distance import cdist
import sys
sys.path.append('../auxiliarScripts')
from dataset_reader import SpotifyPlaylistDataset
from scipy.sparse import csr_matrix, lil_matrix, save_npz, load_npz
from sklearn.metrics import pairwise_distances
from sklearn.metrics.pairwise import cosine_similarity
from IPython.display import display

pd.set_option('display.max_rows', 200)

# %%
sparse_matrix = load_npz('../sparse/spotify_sparse400000.npz')
sparse_matrix
# Out:
# <1000000x2261616 sparse matrix of type '<class 'numpy.float64'>'
# 	with 26206816 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ### Modelo que Retorna Playlists mais Próximas

# %%
class ClosestPlaylists:
    def __init__(self, dataset, distance='cosine'):
        self.dataset = dataset
        self.distance = distance
    
    def recommend(self, playlists, index_playlist):
        #argsort = np.argsort(pairwise_distances(playlists[index_playlist],playlists, metric=self.distance))[0]
        argsort = np.argsort(cosine_similarity(playlists[index_playlist],playlists))[0][::-1]

        # pega a informação da playlist a ser recomendada
        formatted_playlist = self.dataset.read_playlist_formatted(index_playlist)
        # playlist mais proxima da playlist a ser recomendada
        closest_playlist = dataset.read_playlist_formatted(argsort[1])

        # retorna apenas músicas que não tem em comum
        #return closest_playlist
        #return closest_playlist[closest_playlist['track_uri'].isin(formatted_playlist['track_uri'])]
        return closest_playlist[~closest_playlist['track_uri'].isin(formatted_playlist['track_uri'])]

# %%
dataset = SpotifyPlaylistDataset()
model1 = ClosestPlaylists(dataset)
model1.recommend(sparse_matrix, 1001).sort_values(by='track_name')
# Out:
# Carregando dados da slice 0-999
# Carregando dados da slice 1000-1999
# Carregando dados da slice 207000-207999
#     pos artist_name                             track_uri  \
# 36   36   Oh Wonder  spotify:track:6ZeWGilCAL4sgnPWlCYyaj
# 2     2        SOHN  spotify:track:6AYrHFx4DQxdUQeSmAzNYr
# 3     3        SOHN  spotify:track:2WslenTPH7ZIWt8qJbgyed
# 27   27   Oh Wonder  spotify:track:0IIdoxwlGBHhNZQkbYF3yD
# 35   35   Oh Wonder  spotify:track:2KYyhbWmfbW4z8eMhFzme4
# 29   29   Oh Wonder  spotify:track:2kJqNHHGOzLNahukdvlDWN
# 6     6        SOHN  spotify:track:3NlyLB0NdNEW6dWcA1y9Kj
# 39   39   Oh Wonder  spotify:track:2Czp64BykWyWfIssRXQZvT
# 31   31   Oh Wonder  spotify:track:3X3mfRMRaPJRiIMDMQtSkd
# 0     0      Grimes  spotify:track:4f8OIvmWwB2iweLTXlD2mx
# 9     9        SOHN  spotify:track:11Ibjx2iN27rKUqrS2zzPU
# 7     7        SOHN  spotify:track:5MpBlVHG377GcdgooyxO4e
# 26   26   Oh Wonder  spotify:track:6bpBsotzL05UzS1rHsIqk8
# 30   30   Oh Wonder  spotify:track:2QgNcjwEn0vGmTommfszQd
# 37   37   Oh Wonder  spotify:track:6UlVoivrSMVoyhdc5S2tVk
# 5     5        SOHN  spotify:track:6GlpcsxvPqYHHrRNmGo8uu
# 40   40   Oh Wonder  spotify:track:5jOQ5v49S1h496AiNlk682
# 4     4        SOHN  spotify:track:6xuSkHiObB66RhGco317Zc
# 38   38   Oh Wonder  spotify:track:3wwO0kUiwpyzHdkMNoifLR
# 28   28   Oh Wonder  spotify:track:5pLpkaIRobcvPnUmclNv6o
# 34   34   Oh Wonder  spotify:track:77EipMYqP1rGvotKd6i5E3
# 1     1        SOHN  spotify:track:5dJCYzLWPrhlPLhcsrkaBi
# 10   10        SOHN  spotify:track:1UjtgkSgP7ptxSHG4kzc0G
# 8     8        SOHN  spotify:track:0v5dOGRxlnzUKlwKlLb5FN
# 32   32   Oh Wonder  spotify:track:3sZfQB5uYTJmA4QnB8dv7P
# 33   33   Oh Wonder  spotify:track:6Nl5jjykRxa7salssZ0aER
#
#                                artist_uri                     track_name  \
# 36  spotify:artist:5cIc3SBFuBLVxJz58W2tU9                      All We Do
# 2   spotify:artist:6XZYAWJLL8UIbxAqjKj3cg                       Artifice
# 3   spotify:artist:6XZYAWJLL8UIbxAqjKj3cg                     Bloodflows
# 27  spotify:artist:5cIc3SBFuBLVxJz58W2tU9                      Body Gold
# 35  spotify:artist:5cIc3SBFuBLVxJz58W2tU9                         Dazzle
# 29  spotify:artist:5cIc3SBFuBLVxJz58W2tU9                          Drive
# 6   spotify:artist:6XZYAWJLL8UIbxAqjKj3cg                           Fool
# 39  spotify:artist:5cIc3SBFuBLVxJz58W2tU9                     Heart Hope
# 31  spotify:artist:5cIc3SBFuBLVxJz58W2tU9                      Landslide
# 0   spotify:artist:053q0ukIDRgzwTr4vNSwab  Laughing And Not Being Normal
# 9   spotify:artist:6XZYAWJLL8UIbxAqjKj3cg                        Lessons
# 7   spotify:artist:6XZYAWJLL8UIbxAqjKj3cg                         Lights
# 26  spotify:artist:5cIc3SBFuBLVxJz58W2tU9                       Livewire
# 30  spotify:artist:5cIc3SBFuBLVxJz58W2tU9                        Lose It
# 37  spotify:artist:5cIc3SBFuBLVxJz58W2tU9                  Midnight Moon
# 5   spotify:artist:6XZYAWJLL8UIbxAqjKj3cg                      Paralysed
# 40  spotify:artist:5cIc3SBFuBLVxJz58W2tU9                          Plans
# 4   spotify:artist:6XZYAWJLL8UIbxAqjKj3cg                   Ransom Notes
# 38  spotify:artist:5cIc3SBFuBLVxJz58W2tU9                          Shark
# 28  spotify:artist:5cIc3SBFuBLVxJz58W2tU9              Technicolour Beat
# 34  spotify:artist:5cIc3SBFuBLVxJz58W2tU9                       The Rain
# 1   spotify:artist:6XZYAWJLL8UIbxAqjKj3cg                      The Wheel
# 10  spotify:artist:6XZYAWJLL8UIbxAqjKj3cg                        Tremors
# 8   spotify:artist:6XZYAWJLL8UIbxAqjKj3cg                           Veto
# 32  spotify:artist:5cIc3SBFuBLVxJz58W2tU9                    White Blood
# 33  spotify:artist:5cIc3SBFuBLVxJz58W2tU9                    Without You
#
#                                album_uri  duration_ms  album_name
# 36  spotify:album:5GXrievxdXgabSPY9gVq5J       214174   Oh Wonder
# 2   spotify:album:6xGF4UA9pQweZI5yUBFlRq       197977     Tremors
# 3   spotify:album:6xGF4UA9pQweZI5yUBFlRq       261190     Tremors
# 27  spotify:album:37ABUtLPqktcopsBJ7jmXT       184524   Oh Wonder
# 35  spotify:album:37ABUtLPqktcopsBJ7jmXT       187107   Oh Wonder
# 29  spotify:album:37ABUtLPqktcopsBJ7jmXT       196465   Oh Wonder
# 6   spotify:album:6xGF4UA9pQweZI5yUBFlRq       216190     Tremors
# 39  spotify:album:37ABUtLPqktcopsBJ7jmXT       249228   Oh Wonder
# 31  spotify:album:37ABUtLPqktcopsBJ7jmXT       208229   Oh Wonder
# 0   spotify:album:1t9k2P4C88alWEikeJb4mI       107506  Art Angels
# 9   spotify:album:6xGF4UA9pQweZI5yUBFlRq       201150     Tremors
# 7   spotify:album:6xGF4UA9pQweZI5yUBFlRq       269630     Tremors
# 26  spotify:album:37ABUtLPqktcopsBJ7jmXT       203585   Oh Wonder
# 30  spotify:album:37ABUtLPqktcopsBJ7jmXT       229934   Oh Wonder
# 37  spotify:album:37ABUtLPqktcopsBJ7jmXT       210755   Oh Wonder
# 5   spotify:album:6xGF4UA9pQweZI5yUBFlRq       173830     Tremors
# 40  spotify:album:37ABUtLPqktcopsBJ7jmXT       235671   Oh Wonder
# 4   spotify:album:6xGF4UA9pQweZI5yUBFlRq       266004     Tremors
# 38  spotify:album:37ABUtLPqktcopsBJ7jmXT       187424   Oh Wonder
# 28  spotify:album:37ABUtLPqktcopsBJ7jmXT       180119   Oh Wonder
# 34  spotify:album:37ABUtLPqktcopsBJ7jmXT       174083   Oh Wonder
# 1   spotify:album:6xGF4UA9pQweZI5yUBFlRq       233017     Tremors
# 10  spotify:album:6xGF4UA9pQweZI5yUBFlRq       209827     Tremors
# 8   spotify:album:6xGF4UA9pQweZI5yUBFlRq       235804     Tremors
# 32  spotify:album:37ABUtLPqktcopsBJ7jmXT       257426   Oh Wonder
# 33  spotify:album:5GXrievxdXgabSPY9gVq5J       224740   Oh Wonder

# %% [markdown]
# # Modelo que Retorna Músicas que mais ocorrem

# %%
class PlaylistOcurrences:
    def __init__(self, dataset, n_tracks=5, distance='cosine', n_playlists=20):
        self.dataset = dataset
        self.distance = distance
        self.n_tracks = n_tracks
        self.n_playlists = n_playlists
    
    def recommend(self, playlists, index_playlist):
        argsort = np.argsort(cosine_similarity(playlists[index_playlist],playlists))[0][::-1]
        
        music_playlists = [dataset.read_playlist_formatted(argsort[i]) for i in range(1, self.n_playlists+1)]
        concat_playlists = pd.concat(music_playlists, ignore_index=True)
        # adiciona coluna com ocorrencias de cada musicas
        concat_playlists['occurr'] = concat_playlists['track_uri'].apply(
            lambda x: (concat_playlists['track_uri']==x).sum()
        )
        concat_playlists.sort_values(by=['occurr'], ascending=False, inplace=True)
        concat_playlists.drop_duplicates(subset='track_uri', inplace=True)

        # pega a informação da playlist a ser recomendada
        formatted_playlist = self.dataset.read_playlist_formatted(index_playlist)

        # retorna apenas músicas que não tem em comum
        #return concat_playlists[concat_playlists['track_uri'].isin(formatted_playlist['track_uri'])]
        return (concat_playlists[~concat_playlists['track_uri'].isin(
            formatted_playlist['track_uri'])])[:self.n_tracks]

# %%
dataset = SpotifyPlaylistDataset()
model2 = PlaylistOcurrences(dataset, n_playlists=20)
model2.recommend(sparse_matrix, 1001)
# Out:
# Carregando dados da slice 0-999
# Carregando dados da slice 207000-207999
# Carregando dados da slice 276000-276999
# Carregando dados da slice 94000-94999
# Carregando dados da slice 347000-347999
# Carregando dados da slice 287000-287999
# Carregando dados da slice 84000-84999
# Carregando dados da slice 274000-274999
# Carregando dados da slice 263000-263999
# Carregando dados da slice 182000-182999
# Carregando dados da slice 175000-175999
# Carregando dados da slice 365000-365999
# Carregando dados da slice 0-999
# Carregando dados da slice 116000-116999
# Carregando dados da slice 169000-169999
# Carregando dados da slice 318000-318999
# Carregando dados da slice 24000-24999
# Carregando dados da slice 319000-319999
# Carregando dados da slice 369000-369999
# Carregando dados da slice 360000-360999
# Carregando dados da slice 155000-155999
# Carregando dados da slice 1000-1999
#       pos artist_name                             track_uri  \
# 1544   50       Tycho  spotify:track:6koWevx9MqN6efQ6qreIbm
# 1546   52       Tycho  spotify:track:1zTmKEtaxIqi2ByGBLmI3s
# 766   128       Tycho  spotify:track:5E69cnE07kLNNWdlP1XfaE
# 767   129       Tycho  spotify:track:0dE9ro91KUtV5Xi7bDPy6b
# 772   134       Tycho  spotify:track:5MbUyUE6erY9mVgXaecQwR
#
#                                  artist_uri     track_name  \
# 1544  spotify:artist:5oOhM2DFWab8XhSdQiITry         A Walk
# 1546  spotify:artist:5oOhM2DFWab8XhSdQiITry       Daydream
# 766   spotify:artist:5oOhM2DFWab8XhSdQiITry           Dive
# 767   spotify:artist:5oOhM2DFWab8XhSdQiITry  Coastal Brake
# 772   spotify:artist:5oOhM2DFWab8XhSdQiITry          Elegy
#
#                                  album_uri  duration_ms album_name  occurr
# 1544  spotify:album:3I3PmRvn5iFY8i6zzvEcci       316919       Dive       4
# 1546  spotify:album:3I3PmRvn5iFY8i6zzvEcci       334459       Dive       4
# 766   spotify:album:2S20f9bqk2nOcJ6VkP95fk       499790       Dive       3
# 767   spotify:album:3I3PmRvn5iFY8i6zzvEcci       334129       Dive       3
# 772   spotify:album:3I3PmRvn5iFY8i6zzvEcci       263560       Dive       3

# %% [markdown]
# # Modelo Hibrído que Ordena Pelas Mais Similares Baseado em Conteúdo

# %%
tracks = pd.read_csv('../tracks/tracks.csv', index_col='id')
music_ids = tracks[['name', 'artists']]

tracks.drop(['name', 'artists', 'explicit', 'time_signature', 'mode', 'key', 'duration_ms', 'popularity'], 
            axis=1, inplace=True)

def scaler(X, min_=None, max_=None):
    if not min_:
        min_ = X.min()
    if not max_:
        max_ = X.max()
    return X.map(lambda x: (x - min_) / (max_ - min_))

tracks['loudness'] = scaler(tracks['loudness'], min_=-60, max_=0)
tracks['tempo'] = scaler(tracks['tempo'])

# %%
import content_based_recommender

# %%
class Hybrid:
    def __init__(self, tracks, dataset, n_tracks=5, distance='cosine', n_playlists=20, verbose=True, normalize=True):
        self.tracks = tracks
        self.dataset = dataset
        self.distance = distance
        self.n_tracks = n_tracks
        self.n_playlists = n_playlists
        self.verbose = verbose
        self.normalize = normalize
        
    def scaler(self, X, min_, max_):
        return X.map(lambda x: (x - min_) / (max_ - min_))
    
    def recommend(self, playlists, playlist_index, formatted_playlist):
        # pega indices das playlists mais proximas
        argsort = np.argsort(cosine_similarity(playlists[playlist_index],playlists))[0][::-1]
        
        # cria lista com n_playlists playlists mais próximas e junta elas
        music_playlists = [dataset.read_playlist_formatted(argsort[i]) for i in range(1, self.n_playlists+1)]
        concat_playlists = pd.concat(music_playlists, ignore_index=True)
        # adiciona coluna com ocorrencias de cada musica
        concat_playlists['occurr'] = concat_playlists['track_uri'].apply(
            lambda x: (concat_playlists['track_uri']==x).sum()
        )
        # faz sort por ocorrencias e retira duplicatas
        concat_playlists.sort_values(by=['occurr'], ascending=False, inplace=True)
        concat_playlists.drop_duplicates(subset='track_uri', inplace=True)
        
        # pega as tracks não vistas
        #formatted_playlist = self.dataset.read_playlist_formatted(index_playlist)
        unseen_tracks = (concat_playlists[~concat_playlists['track_uri'].isin(
            formatted_playlist['track_uri'])])
        
        #unseen_tracks = unseen_tracks.set_index('track_uri')
        unseen_tracks.set_index('track_uri', inplace=True)
        
        # paga apenas as tracks que mais ocorreram
        max_occurr = unseen_tracks['occurr'].max()
        #tracks_to_recommend = unseen_tracks[unseen_tracks['occurr'] == max_occurr]
        
        # cria as recomendações em cluster com o recomendador baseado em similaridade de conteúdo
        features_df = self.tracks.loc[unseen_tracks.index]
        features_df['occurr'] = unseen_tracks['occurr']
        tracks_names = unseen_tracks[['track_name', 'artist_name']]
        
        user_playlist = formatted_playlist.drop_duplicates(
            subset=['track_uri']).set_index('track_uri')
        user_playlist_features = self.tracks.loc[user_playlist.index]
        user_playlist_features['occurr'] = max_occurr
        
        if (self.normalize==True) :
            user_playlist_features['occurr'] = self.scaler(user_playlist_features['occurr'],
                                                           min_=0, max_=max_occurr)
            features_df['occurr'] = self.scaler(features_df['occurr'],
                                                           min_=0, max_=max_occurr)
        
        cont_rec = content_based_recommender.SimilarityMeans(distance='euclidean')
        cont_rec.fit(features_df, tracks_names)
        recommended, labels, centroids = cont_rec.recommend_clusters(
            user_playlist_features, playlist_in_playlists=False)
        
        if self.verbose:
            for i,r in enumerate(recommended):
                print(f'Músicas pertecentes ao cluster {i+1}:')
                display(user_playlist.loc[user_playlist_features[np.array(labels==i)].index])
                print(f'Recomendação para o cluster {i+1}:')
                display(r)
        
        return recommended, labels, centroids
    
    # função que vai juntar as recomendações dos clusters e ordernar pela ocorrência
    def recommend_k_repeated(self, playlists, index_playlist, formatted_playlist):
        recommended, labels, centroids = self.recommend(playlists, index_playlist, formatted_playlist)
        concat_recomm = pd.concat(recommended).sort_values(
            by='occurr', ascending=False).reset_index().drop_duplicates(
            subset='track_uri').set_index('track_uri')[:self.n_tracks]
        
        return concat_recomm
    
    # função que vai recomendar as músicas do cluster que tem mais músicas
    def recommend_k_large(self, playlists, index_playlist, formatted_playlist):
        '''Pode-se utilizar o cluster com mais músicas, com menor erro ou as músicas que mais se repetiram'''
        recommended, labels, centroids = self.recommend(playlists, index_playlist, formatted_playlist)
        cluster_to_rec = labels.mode().iloc[0]
        return recommended[cluster_to_rec]

# %%
dataset = SpotifyPlaylistDataset()
# Out:
# Carregando dados da slice 0-999

# %%
model3 = Hybrid(tracks, dataset, n_tracks=30, n_playlists=30, verbose=False)
model3.recommend(sparse_matrix, 40000, dataset.read_playlist_formatted(15000))
print()
# Out:
# Carregando dados da slice 15000-15999
# Carregando dados da slice 298000-298999
# Carregando dados da slice 92000-92999
# Carregando dados da slice 338000-338999
# Carregando dados da slice 188000-188999
# Carregando dados da slice 138000-138999
# Carregando dados da slice 154000-154999
# Carregando dados da slice 132000-132999
# Carregando dados da slice 232000-232999
# Carregando dados da slice 178000-178999
# Carregando dados da slice 38000-38999
# Carregando dados da slice 339000-339999
# Carregando dados da slice 251000-251999
# Carregando dados da slice 133000-133999
# Carregando dados da slice 15000-15999
# Carregando dados da slice 70000-70999
# Carregando dados da slice 108000-108999
# Carregando dados da slice 204000-204999
# Carregando dados da slice 74000-74999
# Carregando dados da slice 146000-146999
# Carregando dados da slice 225000-225999
# Carregando dados da slice 215000-215999
# Carregando dados da slice 226000-226999
# Carregando dados da slice 169000-169999
# Carregando dados da slice 197000-197999
# Carregando dados da slice 298000-298999
# Carregando dados da slice 79000-79999
# Carregando dados da slice 288000-288999
# Carregando dados da slice 156000-156999
# Carregando dados da slice 353000-353999
# Carregando dados da slice 331000-331999

# %%
#model4 = Hybrid(tracks, dataset, n_playlists=20)
#model4.recommend(sparse_matrix, 432421, dataset.read_playlist_formatted(432421))
print()

# %%
class RPrecisionTracks:
    def __init__(self, sparse_matrix, dataset, model, n_playlists=10_000):
        self.sparse_matrix = lil_matrix(sparse_matrix)
        self.dataset = dataset
        self.model = model
        self.n_playlists = n_playlists
        
    def precision(self, recommended, test_tracks):
        test_index = test_tracks.set_index('track_uri').index
        recommended_index = recommended.index
        inters = test_index.intersection(recommended_index)
        
        return len(inters) / len(test_tracks)
    
    def recommend_partial_playlist(self, index):
        og_playlist = self.dataset.read_playlist_formatted(index)
        half = len(og_playlist) // 2
        playlist_train = og_playlist.iloc[:half]
        playlist_test = og_playlist.iloc[half:]
        
        test_tracks_pos = tracks.index.isin(playlist_test['track_uri'])
        for i,pos in enumerate(test_tracks_pos):
            if pos:
                self.sparse_matrix[index, i] = 0
        
        rec = self.model(csr_matrix(self.sparse_matrix), index, playlist_train)
        return self.precision(rec, playlist_test)
        
        
    def evaluate(self):
        precisions = np.zeros(self.n_playlists)
        i = 0
        s = 0
        while s < self.n_playlists: 
            playlist = self.dataset.read_playlist_formatted(i)
            if len(playlist) >= 10:
                precisions[s] = self.recommend_partial_playlist(i)
                s += 1
            i += 1
        return np.mean(precisions)

# %%
rp = RPrecisionTracks(sparse_matrix, dataset, model3.recommend_k_large, n_playlists=10)
rp.evaluate()
# Out:
# Carregando dados da slice 0-999
# Carregando dados da slice 346000-346999
# Carregando dados da slice 109000-109999
# Carregando dados da slice 12000-12999
# Carregando dados da slice 391000-391999
# Carregando dados da slice 46000-46999
# Carregando dados da slice 225000-225999
# Carregando dados da slice 208000-208999
# Carregando dados da slice 321000-321999
# Carregando dados da slice 359000-359999
# Carregando dados da slice 106000-106999
# Carregando dados da slice 275000-275999
# Carregando dados da slice 203000-203999
# Carregando dados da slice 157000-157999
# Carregando dados da slice 162000-162999
# Carregando dados da slice 323000-323999
# Carregando dados da slice 74000-74999
# Carregando dados da slice 4000-4999
# Carregando dados da slice 93000-93999
# Carregando dados da slice 262000-262999
# Carregando dados da slice 5000-5999
# Carregando dados da slice 345000-345999
# Carregando dados da slice 337000-337999
# Carregando dados da slice 284000-284999
# Carregando dados da slice 295000-295999
# Carregando dados da slice 223000-223999
# Carregando dados da slice 291000-291999
# Carregando dados da slice 290000-290999
# Carregando dados da slice 383000-383999
# Carregando dados da slice 232000-232999
# Carregando dados da slice 352000-352999
# Carregando dados da slice 0-999
# Carregando dados da slice 201000-201999
# Carregando dados da slice 276000-276999
# Carregando dados da slice 219000-219999
# Carregando dados da slice 388000-388999
# Carregando dados da slice 32000-32999
# Carregando dados da slice 390000-390999
# Carregando dados da slice 144000-144999
# Carregando dados da slice 205000-205999
# Carregando dados da slice 92000-92999
# Carregando dados da slice 160000-160999
# Carregando dados da slice 335000-335999
# Carregando dados da slice 338000-338999
# Carregando dados da slice 364000-364999
# Carregando dados da slice 348000-348999
# Carregando dados da slice 30000-30999
# Carregando dados da slice 163000-163999
# Carregando dados da slice 220000-220999
# Carregando dados da slice 190000-190999
# Carregando dados da slice 146000-146999
# Carregando dados da slice 307000-307999
# Carregando dados da slice 398000-398999
# Carregando dados da slice 33000-33999
# Carregando dados da slice 393000-393999
# Carregando dados da slice 267000-267999
# Carregando dados da slice 29000-29999
# Carregando dados da slice 254000-254999
# Carregando dados da slice 126000-126999
# Carregando dados da slice 369000-369999
# Carregando dados da slice 385000-385999
# Carregando dados da slice 252000-252999
# Carregando dados da slice 0-999
# Carregando dados da slice 222000-222999
# Carregando dados da slice 243000-243999
# Carregando dados da slice 209000-209999
# Carregando dados da slice 357000-357999
# Carregando dados da slice 125000-125999
# Carregando dados da slice 103000-103999
# Carregando dados da slice 385000-385999
# Carregando dados da slice 304000-304999
# Carregando dados da slice 317000-317999
# Carregando dados da slice 21000-21999
# Carregando dados da slice 239000-239999
# Carregando dados da slice 71000-71999
# Carregando dados da slice 378000-378999
# Carregando dados da slice 182000-182999
# Carregando dados da slice 310000-310999
# Carregando dados da slice 191000-191999
# Carregando dados da slice 151000-151999
# Carregando dados da slice 114000-114999
# Carregando dados da slice 367000-367999
# Carregando dados da slice 175000-175999
# Carregando dados da slice 29000-29999
# Carregando dados da slice 41000-41999
# Carregando dados da slice 301000-301999
# Carregando dados da slice 219000-219999
# Carregando dados da slice 271000-271999
# Carregando dados da slice 94000-94999
# Carregando dados da slice 302000-302999
# Carregando dados da slice 238000-238999
# Carregando dados da slice 306000-306999
# Carregando dados da slice 264000-264999
# Carregando dados da slice 0-999
# Carregando dados da slice 109000-109999
# Carregando dados da slice 43000-43999
# Carregando dados da slice 172000-172999
# Carregando dados da slice 356000-356999
# Carregando dados da slice 184000-184999
# Carregando dados da slice 268000-268999
# Carregando dados da slice 139000-139999
# Carregando dados da slice 395000-395999
# Carregando dados da slice 198000-198999
# Carregando dados da slice 275000-275999
# Carregando dados da slice 308000-308999
# Carregando dados da slice 270000-270999
# Carregando dados da slice 73000-73999
# Carregando dados da slice 251000-251999
# Carregando dados da slice 269000-269999
# Carregando dados da slice 324000-324999
# Carregando dados da slice 253000-253999
# Carregando dados da slice 371000-371999
# Carregando dados da slice 176000-176999
# Carregando dados da slice 321000-321999
# Carregando dados da slice 337000-337999
# Carregando dados da slice 103000-103999
# Carregando dados da slice 333000-333999
# Carregando dados da slice 308000-308999
# Carregando dados da slice 141000-141999
# Carregando dados da slice 308000-308999
# Carregando dados da slice 343000-343999
# Carregando dados da slice 199000-199999
# Carregando dados da slice 163000-163999
# Carregando dados da slice 0-999
# Carregando dados da slice 47000-47999
# Carregando dados da slice 217000-217999
# Carregando dados da slice 10000-10999
# Carregando dados da slice 230000-230999
# Carregando dados da slice 265000-265999
# Carregando dados da slice 86000-86999
# Carregando dados da slice 377000-377999
# Carregando dados da slice 8000-8999
# Carregando dados da slice 16000-16999
# Carregando dados da slice 389000-389999
# Carregando dados da slice 196000-196999
# Carregando dados da slice 185000-185999
# Carregando dados da slice 317000-317999
# Carregando dados da slice 325000-325999
# Carregando dados da slice 208000-208999
# Carregando dados da slice 85000-85999
# Carregando dados da slice 226000-226999
# Carregando dados da slice 387000-387999
# Carregando dados da slice 39000-39999
# Carregando dados da slice 369000-369999
# Carregando dados da slice 307000-307999
# Carregando dados da slice 173000-173999
# Carregando dados da slice 15000-15999
# Carregando dados da slice 140000-140999
# Carregando dados da slice 294000-294999
# Carregando dados da slice 179000-179999
# Carregando dados da slice 229000-229999
# Carregando dados da slice 91000-91999
# Carregando dados da slice 89000-89999
# Carregando dados da slice 113000-113999
# Carregando dados da slice 0-999
# Carregando dados da slice 60000-60999
# Carregando dados da slice 243000-243999
# Carregando dados da slice 121000-121999
# Carregando dados da slice 235000-235999
# Carregando dados da slice 335000-335999
# Carregando dados da slice 207000-207999
# Carregando dados da slice 137000-137999
# Carregando dados da slice 85000-85999
# Carregando dados da slice 264000-264999
# Carregando dados da slice 171000-171999
# Carregando dados da slice 233000-233999
# Carregando dados da slice 23000-23999
# Carregando dados da slice 112000-112999
# Carregando dados da slice 368000-368999
# Carregando dados da slice 189000-189999
# Carregando dados da slice 75000-75999
# Carregando dados da slice 276000-276999
# Carregando dados da slice 210000-210999
# Carregando dados da slice 178000-178999
# Carregando dados da slice 74000-74999
# Carregando dados da slice 101000-101999
# Carregando dados da slice 193000-193999
# Carregando dados da slice 57000-57999
# Carregando dados da slice 297000-297999
# Carregando dados da slice 260000-260999
# Carregando dados da slice 291000-291999
# Carregando dados da slice 389000-389999
# Carregando dados da slice 339000-339999
# Carregando dados da slice 18000-18999
# Carregando dados da slice 0-999
# Carregando dados da slice 146000-146999
# Carregando dados da slice 206000-206999
# Carregando dados da slice 169000-169999
# Carregando dados da slice 76000-76999
# Carregando dados da slice 201000-201999
# Carregando dados da slice 120000-120999
# Carregando dados da slice 244000-244999
# Carregando dados da slice 88000-88999
# Carregando dados da slice 295000-295999
# Carregando dados da slice 92000-92999
# Carregando dados da slice 248000-248999
# Carregando dados da slice 355000-355999
# Carregando dados da slice 360000-360999
# Carregando dados da slice 372000-372999
# Carregando dados da slice 308000-308999
# Carregando dados da slice 280000-280999
# Carregando dados da slice 199000-199999
# Carregando dados da slice 244000-244999
# Carregando dados da slice 354000-354999
# Carregando dados da slice 34000-34999
# Carregando dados da slice 367000-367999
# Carregando dados da slice 212000-212999
# Carregando dados da slice 69000-69999
# Carregando dados da slice 22000-22999
# Carregando dados da slice 233000-233999
# Carregando dados da slice 292000-292999
# Carregando dados da slice 249000-249999
# Carregando dados da slice 244000-244999
# Carregando dados da slice 253000-253999
# Carregando dados da slice 373000-373999
# Carregando dados da slice 0-999
# Carregando dados da slice 375000-375999
# Carregando dados da slice 376000-376999
# Carregando dados da slice 205000-205999
# Carregando dados da slice 194000-194999
# Carregando dados da slice 55000-55999
# Carregando dados da slice 75000-75999
# Carregando dados da slice 329000-329999
# Carregando dados da slice 396000-396999
# Carregando dados da slice 313000-313999
# Carregando dados da slice 259000-259999
# Carregando dados da slice 359000-359999
# Carregando dados da slice 143000-143999
# Carregando dados da slice 126000-126999
# Carregando dados da slice 368000-368999
# Carregando dados da slice 48000-48999
# Carregando dados da slice 322000-322999
# Carregando dados da slice 283000-283999
# Carregando dados da slice 118000-118999
# Carregando dados da slice 231000-231999
# Carregando dados da slice 120000-120999
# Carregando dados da slice 395000-395999
# Carregando dados da slice 393000-393999
# Carregando dados da slice 97000-97999
# Carregando dados da slice 119000-119999
# Carregando dados da slice 31000-31999
# Carregando dados da slice 223000-223999
# Carregando dados da slice 364000-364999
# Carregando dados da slice 204000-204999
# Carregando dados da slice 384000-384999
# Carregando dados da slice 197000-197999
# Carregando dados da slice 0-999
# Carregando dados da slice 69000-69999
# Carregando dados da slice 147000-147999
# Carregando dados da slice 102000-102999
# Carregando dados da slice 234000-234999
# Carregando dados da slice 357000-357999
# Carregando dados da slice 345000-345999
# Carregando dados da slice 149000-149999
# Carregando dados da slice 137000-137999
# Carregando dados da slice 118000-118999
# Carregando dados da slice 384000-384999
# Carregando dados da slice 151000-151999
# Carregando dados da slice 29000-29999
# Carregando dados da slice 134000-134999
# Carregando dados da slice 109000-109999
# Carregando dados da slice 14000-14999
# Carregando dados da slice 257000-257999
# Carregando dados da slice 270000-270999
# Carregando dados da slice 129000-129999
# Carregando dados da slice 247000-247999
# Carregando dados da slice 69000-69999
# Carregando dados da slice 362000-362999
# Carregando dados da slice 32000-32999
# Carregando dados da slice 131000-131999
# Carregando dados da slice 301000-301999
# Carregando dados da slice 289000-289999
# Carregando dados da slice 283000-283999
# Carregando dados da slice 382000-382999
# Carregando dados da slice 292000-292999
# Carregando dados da slice 306000-306999
# Carregando dados da slice 24000-24999
# Carregando dados da slice 0-999
# Carregando dados da slice 70000-70999
# Carregando dados da slice 76000-76999
# Carregando dados da slice 66000-66999
# Carregando dados da slice 185000-185999
# Carregando dados da slice 152000-152999
# Carregando dados da slice 176000-176999
# Carregando dados da slice 187000-187999
# Carregando dados da slice 64000-64999
# Carregando dados da slice 267000-267999
# Carregando dados da slice 10000-10999
# Carregando dados da slice 341000-341999
# Carregando dados da slice 336000-336999
# Carregando dados da slice 293000-293999
# Carregando dados da slice 135000-135999
# Carregando dados da slice 164000-164999
# Carregando dados da slice 144000-144999
# Carregando dados da slice 313000-313999
# Carregando dados da slice 314000-314999
# Carregando dados da slice 86000-86999
# Carregando dados da slice 11000-11999
# Carregando dados da slice 376000-376999
# Carregando dados da slice 260000-260999
# Carregando dados da slice 330000-330999
# Carregando dados da slice 248000-248999
# Carregando dados da slice 61000-61999
# Carregando dados da slice 365000-365999
# Carregando dados da slice 273000-273999
# Carregando dados da slice 206000-206999
# Carregando dados da slice 157000-157999
# Carregando dados da slice 63000-63999
# Carregando dados da slice 0-999
# Carregando dados da slice 393000-393999
# Carregando dados da slice 246000-246999
# Carregando dados da slice 208000-208999
# Carregando dados da slice 63000-63999
# Carregando dados da slice 32000-32999
# Carregando dados da slice 43000-43999
# Carregando dados da slice 232000-232999
# Carregando dados da slice 69000-69999
# Carregando dados da slice 334000-334999
# Carregando dados da slice 273000-273999
# Carregando dados da slice 248000-248999
# Carregando dados da slice 376000-376999
# Carregando dados da slice 311000-311999
# Carregando dados da slice 194000-194999
# Carregando dados da slice 87000-87999
# Carregando dados da slice 249000-249999
# Carregando dados da slice 114000-114999
# Carregando dados da slice 310000-310999
# Carregando dados da slice 228000-228999
# Carregando dados da slice 137000-137999
# Carregando dados da slice 22000-22999
# Carregando dados da slice 81000-81999
# Carregando dados da slice 141000-141999
# Carregando dados da slice 119000-119999
# Carregando dados da slice 108000-108999
# Carregando dados da slice 90000-90999
# Carregando dados da slice 118000-118999
# Carregando dados da slice 228000-228999
# Carregando dados da slice 290000-290999
# Carregando dados da slice 0-999
# Carregando dados da slice 198000-198999
# Carregando dados da slice 145000-145999
# Carregando dados da slice 339000-339999
# Carregando dados da slice 207000-207999
# Carregando dados da slice 241000-241999
# Carregando dados da slice 28000-28999
# Carregando dados da slice 82000-82999
# Carregando dados da slice 13000-13999
# Carregando dados da slice 139000-139999
# Carregando dados da slice 115000-115999
# Carregando dados da slice 353000-353999
# Carregando dados da slice 321000-321999
# Carregando dados da slice 148000-148999
# Carregando dados da slice 295000-295999
# Carregando dados da slice 283000-283999
# Carregando dados da slice 329000-329999
# Carregando dados da slice 20000-20999
# Carregando dados da slice 98000-98999
# Carregando dados da slice 331000-331999
# Carregando dados da slice 284000-284999
# Carregando dados da slice 264000-264999
# Carregando dados da slice 355000-355999
# Carregando dados da slice 147000-147999
# Carregando dados da slice 42000-42999
# Carregando dados da slice 254000-254999
# Carregando dados da slice 151000-151999
# Carregando dados da slice 10000-10999
# Carregando dados da slice 37000-37999
# Carregando dados da slice 0-999
# Carregando dados da slice 54000-54999
# Carregando dados da slice 225000-225999
# Carregando dados da slice 395000-395999
# Carregando dados da slice 377000-377999
# Carregando dados da slice 251000-251999
# Carregando dados da slice 326000-326999
# Carregando dados da slice 72000-72999
# Carregando dados da slice 390000-390999
# Carregando dados da slice 302000-302999
# Carregando dados da slice 251000-251999
# Carregando dados da slice 305000-305999
# Carregando dados da slice 84000-84999
# Carregando dados da slice 213000-213999
# Carregando dados da slice 151000-151999
# Carregando dados da slice 389000-389999
# Carregando dados da slice 89000-89999
# Carregando dados da slice 185000-185999
# Carregando dados da slice 329000-329999
# Carregando dados da slice 231000-231999
# Carregando dados da slice 247000-247999
# Carregando dados da slice 283000-283999
# Carregando dados da slice 202000-202999
# Carregando dados da slice 326000-326999
# Carregando dados da slice 105000-105999
# Carregando dados da slice 61000-61999
# Carregando dados da slice 232000-232999
# Carregando dados da slice 333000-333999
# Carregando dados da slice 35000-35999
# Carregando dados da slice 323000-323999
# Carregando dados da slice 63000-63999
# Carregando dados da slice 0-999
# Carregando dados da slice 211000-211999
# Carregando dados da slice 33000-33999
# Carregando dados da slice 123000-123999
# Carregando dados da slice 203000-203999
# Carregando dados da slice 358000-358999
# Carregando dados da slice 227000-227999
# Carregando dados da slice 26000-26999
# Carregando dados da slice 128000-128999
# Carregando dados da slice 335000-335999
# Carregando dados da slice 237000-237999
# Carregando dados da slice 103000-103999
# Carregando dados da slice 167000-167999
# Carregando dados da slice 257000-257999
# Carregando dados da slice 47000-47999
# Carregando dados da slice 3000-3999
# Carregando dados da slice 240000-240999
# Carregando dados da slice 394000-394999
# Carregando dados da slice 353000-353999
# Carregando dados da slice 359000-359999
# Carregando dados da slice 382000-382999
# Carregando dados da slice 98000-98999
# Carregando dados da slice 310000-310999
# Carregando dados da slice 385000-385999
# Carregando dados da slice 349000-349999
# Carregando dados da slice 365000-365999
# Carregando dados da slice 347000-347999
# Carregando dados da slice 173000-173999
# Carregando dados da slice 346000-346999
# Carregando dados da slice 45000-45999
# Carregando dados da slice 243000-243999
# Carregando dados da slice 0-999
# Carregando dados da slice 254000-254999
# Carregando dados da slice 267000-267999
# Carregando dados da slice 6000-6999
# Carregando dados da slice 196000-196999
# Carregando dados da slice 288000-288999
# Carregando dados da slice 284000-284999
# Carregando dados da slice 341000-341999
# Carregando dados da slice 299000-299999
# Carregando dados da slice 389000-389999
# Carregando dados da slice 393000-393999
# Carregando dados da slice 351000-351999
# Carregando dados da slice 278000-278999
# Carregando dados da slice 96000-96999
# Carregando dados da slice 190000-190999
# Carregando dados da slice 267000-267999
# Carregando dados da slice 225000-225999
# Carregando dados da slice 107000-107999
# Carregando dados da slice 140000-140999
# Carregando dados da slice 184000-184999
# Carregando dados da slice 310000-310999
# Carregando dados da slice 257000-257999
# Carregando dados da slice 79000-79999
# Carregando dados da slice 386000-386999
# Carregando dados da slice 368000-368999
# Carregando dados da slice 163000-163999
# Carregando dados da slice 237000-237999
# Carregando dados da slice 163000-163999
# Carregando dados da slice 266000-266999
# Carregando dados da slice 121000-121999
# Carregando dados da slice 120000-120999
# Carregando dados da slice 0-999
# Carregando dados da slice 339000-339999
# Carregando dados da slice 340000-340999
# Carregando dados da slice 334000-334999
# Carregando dados da slice 148000-148999
# Carregando dados da slice 27000-27999
# Carregando dados da slice 187000-187999
# Carregando dados da slice 112000-112999
# Carregando dados da slice 392000-392999
# Carregando dados da slice 94000-94999
# Carregando dados da slice 115000-115999
# Carregando dados da slice 316000-316999
# Carregando dados da slice 88000-88999
# Carregando dados da slice 316000-316999
# Carregando dados da slice 158000-158999
# Carregando dados da slice 277000-277999
# Carregando dados da slice 375000-375999
# Carregando dados da slice 110000-110999
# Carregando dados da slice 200000-200999
# Carregando dados da slice 226000-226999
# Carregando dados da slice 30000-30999
# Carregando dados da slice 208000-208999
# Carregando dados da slice 52000-52999
# Carregando dados da slice 124000-124999
# Carregando dados da slice 9000-9999
# Carregando dados da slice 189000-189999
# Carregando dados da slice 308000-308999
# Carregando dados da slice 180000-180999
# Carregando dados da slice 81000-81999
# Carregando dados da slice 93000-93999
# Carregando dados da slice 249000-249999
# Carregando dados da slice 0-999
# Carregando dados da slice 143000-143999
# Carregando dados da slice 331000-331999
# Carregando dados da slice 9000-9999
# Carregando dados da slice 14000-14999
# Carregando dados da slice 24000-24999
# Carregando dados da slice 323000-323999
# Carregando dados da slice 328000-328999
# Carregando dados da slice 375000-375999
# Carregando dados da slice 393000-393999
# Carregando dados da slice 254000-254999
# Carregando dados da slice 74000-74999
# Carregando dados da slice 52000-52999
# Carregando dados da slice 108000-108999
# Carregando dados da slice 129000-129999
# Carregando dados da slice 190000-190999
# Carregando dados da slice 115000-115999
# Carregando dados da slice 120000-120999
# Carregando dados da slice 255000-255999
# Carregando dados da slice 375000-375999
# Carregando dados da slice 70000-70999
# Carregando dados da slice 80000-80999
# Carregando dados da slice 268000-268999
# Carregando dados da slice 111000-111999
# Carregando dados da slice 27000-27999
# Carregando dados da slice 192000-192999
# Carregando dados da slice 12000-12999
# Carregando dados da slice 14000-14999
# Carregando dados da slice 117000-117999
# Carregando dados da slice 124000-124999
# Carregando dados da slice 11000-11999
# Carregando dados da slice 0-999
# Carregando dados da slice 277000-277999
# Carregando dados da slice 10000-10999
# Carregando dados da slice 324000-324999
# Carregando dados da slice 366000-366999
# Carregando dados da slice 24000-24999
# Carregando dados da slice 103000-103999
# Carregando dados da slice 387000-387999
# Carregando dados da slice 58000-58999
# Carregando dados da slice 166000-166999
# Carregando dados da slice 97000-97999
# Carregando dados da slice 78000-78999
# Carregando dados da slice 64000-64999
# Carregando dados da slice 161000-161999
# Carregando dados da slice 217000-217999
# Carregando dados da slice 322000-322999
# Carregando dados da slice 37000-37999
# Carregando dados da slice 150000-150999
# Carregando dados da slice 245000-245999
# Carregando dados da slice 178000-178999
# Carregando dados da slice 54000-54999
# Carregando dados da slice 78000-78999
# Carregando dados da slice 216000-216999
# Carregando dados da slice 154000-154999
# Carregando dados da slice 273000-273999
# Carregando dados da slice 112000-112999
# Carregando dados da slice 138000-138999
# Carregando dados da slice 79000-79999
# Carregando dados da slice 170000-170999
# Carregando dados da slice 379000-379999
# Carregando dados da slice 264000-264999
# Carregando dados da slice 0-999
# Carregando dados da slice 248000-248999
# Carregando dados da slice 52000-52999
# Carregando dados da slice 28000-28999
# Carregando dados da slice 305000-305999
# Carregando dados da slice 214000-214999
# Carregando dados da slice 258000-258999
# Carregando dados da slice 23000-23999
# Carregando dados da slice 332000-332999
# Carregando dados da slice 76000-76999
# Carregando dados da slice 247000-247999
# Carregando dados da slice 92000-92999
# Carregando dados da slice 284000-284999
# Carregando dados da slice 315000-315999
# Carregando dados da slice 232000-232999
# Carregando dados da slice 387000-387999
# Carregando dados da slice 73000-73999
# Carregando dados da slice 163000-163999
# Carregando dados da slice 392000-392999
# Carregando dados da slice 383000-383999
# Carregando dados da slice 187000-187999
# Carregando dados da slice 275000-275999
# Carregando dados da slice 87000-87999
# Carregando dados da slice 368000-368999
# Carregando dados da slice 293000-293999
# Carregando dados da slice 135000-135999
# Carregando dados da slice 7000-7999
# Carregando dados da slice 101000-101999
# Carregando dados da slice 319000-319999
# Carregando dados da slice 229000-229999
# Carregando dados da slice 175000-175999
# Carregando dados da slice 0-999
# Carregando dados da slice 70000-70999
# Carregando dados da slice 207000-207999
# Carregando dados da slice 380000-380999
# Carregando dados da slice 292000-292999
# Carregando dados da slice 118000-118999
# Carregando dados da slice 378000-378999
# Carregando dados da slice 11000-11999
# Carregando dados da slice 178000-178999
# Carregando dados da slice 60000-60999
# Carregando dados da slice 304000-304999
# Carregando dados da slice 200000-200999
# Carregando dados da slice 259000-259999
# Carregando dados da slice 305000-305999
# Carregando dados da slice 61000-61999
# Carregando dados da slice 229000-229999
# Carregando dados da slice 148000-148999
# Carregando dados da slice 109000-109999
# Carregando dados da slice 393000-393999
# Carregando dados da slice 11000-11999
# Carregando dados da slice 144000-144999
# Carregando dados da slice 36000-36999
# Carregando dados da slice 192000-192999
# Carregando dados da slice 25000-25999
# Carregando dados da slice 19000-19999
# Carregando dados da slice 304000-304999
# Carregando dados da slice 167000-167999
# Carregando dados da slice 259000-259999
# Carregando dados da slice 28000-28999
# Carregando dados da slice 105000-105999
# Carregando dados da slice 0-999
# Carregando dados da slice 194000-194999
# Carregando dados da slice 178000-178999
# Carregando dados da slice 399000-399999
# Carregando dados da slice 45000-45999
# Carregando dados da slice 222000-222999
# Carregando dados da slice 294000-294999
# Carregando dados da slice 114000-114999
# Carregando dados da slice 244000-244999
# Carregando dados da slice 197000-197999
# Carregando dados da slice 368000-368999
# Carregando dados da slice 21000-21999
# Carregando dados da slice 319000-319999
# Carregando dados da slice 207000-207999
# Carregando dados da slice 89000-89999
# Carregando dados da slice 92000-92999
# Carregando dados da slice 386000-386999
# Carregando dados da slice 278000-278999
# Carregando dados da slice 65000-65999
# Carregando dados da slice 170000-170999
# Carregando dados da slice 395000-395999
# Carregando dados da slice 297000-297999
# Carregando dados da slice 60000-60999
# Carregando dados da slice 176000-176999
# Carregando dados da slice 137000-137999
# Carregando dados da slice 183000-183999
# Carregando dados da slice 340000-340999
# Carregando dados da slice 295000-295999
# Carregando dados da slice 394000-394999
# Carregando dados da slice 347000-347999
# Carregando dados da slice 152000-152999
# Carregando dados da slice 0-999
# Carregando dados da slice 359000-359999
# Carregando dados da slice 34000-34999
# Carregando dados da slice 312000-312999
# Carregando dados da slice 24000-24999
# Carregando dados da slice 249000-249999
# Carregando dados da slice 345000-345999
# Carregando dados da slice 170000-170999
# Carregando dados da slice 145000-145999
# Carregando dados da slice 336000-336999
# Carregando dados da slice 29000-29999
# Carregando dados da slice 355000-355999
# Carregando dados da slice 90000-90999
# Carregando dados da slice 4000-4999
# Carregando dados da slice 33000-33999
# Carregando dados da slice 145000-145999
# Carregando dados da slice 296000-296999
# Carregando dados da slice 9000-9999
# Carregando dados da slice 290000-290999
# Carregando dados da slice 341000-341999
# Carregando dados da slice 257000-257999
# Carregando dados da slice 109000-109999
# Carregando dados da slice 27000-27999
# Carregando dados da slice 266000-266999
# Carregando dados da slice 47000-47999
# Carregando dados da slice 191000-191999
# Carregando dados da slice 183000-183999
# Carregando dados da slice 70000-70999
# Carregando dados da slice 305000-305999
# Carregando dados da slice 201000-201999
# Carregando dados da slice 95000-95999
# Carregando dados da slice 0-999
# Carregando dados da slice 85000-85999
# Carregando dados da slice 233000-233999
# Carregando dados da slice 386000-386999
# Carregando dados da slice 18000-18999
# Carregando dados da slice 260000-260999
# Carregando dados da slice 258000-258999
# Carregando dados da slice 156000-156999
# Carregando dados da slice 176000-176999
# Carregando dados da slice 397000-397999
# Carregando dados da slice 68000-68999
# Carregando dados da slice 29000-29999
# Carregando dados da slice 227000-227999
# Carregando dados da slice 270000-270999
# Carregando dados da slice 294000-294999
# Carregando dados da slice 101000-101999
# Carregando dados da slice 263000-263999
# Carregando dados da slice 143000-143999
# Carregando dados da slice 360000-360999
# Carregando dados da slice 87000-87999
# Carregando dados da slice 313000-313999
# Carregando dados da slice 115000-115999
# Carregando dados da slice 234000-234999
# Carregando dados da slice 278000-278999
# Carregando dados da slice 215000-215999
# Carregando dados da slice 108000-108999
# Carregando dados da slice 40000-40999
# Carregando dados da slice 60000-60999
# Carregando dados da slice 238000-238999
# Carregando dados da slice 192000-192999
# Carregando dados da slice 382000-382999
# Carregando dados da slice 0-999
# Carregando dados da slice 328000-328999
# Carregando dados da slice 259000-259999
# Carregando dados da slice 236000-236999
# Carregando dados da slice 98000-98999
# Carregando dados da slice 258000-258999
# Carregando dados da slice 269000-269999
# Carregando dados da slice 238000-238999
# Carregando dados da slice 130000-130999
# Carregando dados da slice 91000-91999
# Carregando dados da slice 136000-136999
# Carregando dados da slice 311000-311999
# Carregando dados da slice 282000-282999
# Carregando dados da slice 74000-74999
# Carregando dados da slice 11000-11999
# Carregando dados da slice 203000-203999
# Carregando dados da slice 150000-150999
# Carregando dados da slice 22000-22999
# Carregando dados da slice 136000-136999
# Carregando dados da slice 18000-18999
# Carregando dados da slice 46000-46999
# Carregando dados da slice 212000-212999
# Carregando dados da slice 84000-84999
# Carregando dados da slice 246000-246999
# Carregando dados da slice 204000-204999
# Carregando dados da slice 316000-316999
# Carregando dados da slice 399000-399999
# Carregando dados da slice 293000-293999
# Carregando dados da slice 219000-219999
# Carregando dados da slice 244000-244999
# Carregando dados da slice 201000-201999
# Carregando dados da slice 0-999
# Carregando dados da slice 191000-191999
# Carregando dados da slice 12000-12999
# Carregando dados da slice 174000-174999
# Carregando dados da slice 292000-292999
# Carregando dados da slice 276000-276999
# Carregando dados da slice 301000-301999
# Carregando dados da slice 266000-266999
# Carregando dados da slice 147000-147999
# Carregando dados da slice 71000-71999
# Carregando dados da slice 36000-36999
# Carregando dados da slice 181000-181999
# Carregando dados da slice 225000-225999
# Carregando dados da slice 245000-245999
# Carregando dados da slice 40000-40999
# Carregando dados da slice 84000-84999
# Carregando dados da slice 55000-55999
# Carregando dados da slice 367000-367999
# Carregando dados da slice 128000-128999
# Carregando dados da slice 288000-288999
# Carregando dados da slice 46000-46999
# Carregando dados da slice 345000-345999
# Carregando dados da slice 287000-287999
# Carregando dados da slice 65000-65999
# Carregando dados da slice 279000-279999
# Carregando dados da slice 321000-321999
# Carregando dados da slice 32000-32999
# Carregando dados da slice 85000-85999
# Carregando dados da slice 201000-201999
# Carregando dados da slice 137000-137999
# Carregando dados da slice 30000-30999
# Carregando dados da slice 0-999
# Carregando dados da slice 30000-30999
# Carregando dados da slice 10000-10999
# Carregando dados da slice 266000-266999
# Carregando dados da slice 265000-265999
# Carregando dados da slice 240000-240999
# Carregando dados da slice 307000-307999
# Carregando dados da slice 296000-296999
# Carregando dados da slice 362000-362999
# Carregando dados da slice 3000-3999
# Carregando dados da slice 62000-62999
# Carregando dados da slice 271000-271999
# Carregando dados da slice 231000-231999
# Carregando dados da slice 182000-182999
# Carregando dados da slice 393000-393999
# Carregando dados da slice 287000-287999
# Carregando dados da slice 210000-210999
# Carregando dados da slice 370000-370999
# Carregando dados da slice 244000-244999
# Carregando dados da slice 234000-234999
# Carregando dados da slice 184000-184999
# Carregando dados da slice 121000-121999
# Carregando dados da slice 111000-111999
# Carregando dados da slice 3000-3999
# Carregando dados da slice 178000-178999
# Carregando dados da slice 99000-99999
# Carregando dados da slice 105000-105999
# Carregando dados da slice 69000-69999
# Carregando dados da slice 350000-350999
# Carregando dados da slice 96000-96999
# Carregando dados da slice 131000-131999
# Carregando dados da slice 0-999
# Carregando dados da slice 210000-210999
# Carregando dados da slice 37000-37999
# Carregando dados da slice 17000-17999
# Carregando dados da slice 123000-123999
# Carregando dados da slice 7000-7999
# Carregando dados da slice 31000-31999
# Carregando dados da slice 256000-256999
# Carregando dados da slice 225000-225999
# Carregando dados da slice 55000-55999
# Carregando dados da slice 122000-122999
# Carregando dados da slice 291000-291999
# Carregando dados da slice 344000-344999
# Carregando dados da slice 259000-259999
# Carregando dados da slice 106000-106999
# Carregando dados da slice 45000-45999
# Carregando dados da slice 293000-293999
# Carregando dados da slice 282000-282999
# Carregando dados da slice 37000-37999
# Carregando dados da slice 311000-311999
# Carregando dados da slice 5000-5999
# Carregando dados da slice 69000-69999
# Carregando dados da slice 219000-219999
# Carregando dados da slice 61000-61999
# Carregando dados da slice 335000-335999
# Carregando dados da slice 244000-244999
# Carregando dados da slice 6000-6999
# Carregando dados da slice 167000-167999
# Carregando dados da slice 368000-368999
# Carregando dados da slice 264000-264999
# Carregando dados da slice 396000-396999
# Carregando dados da slice 0-999
# Carregando dados da slice 1000-1999
# Carregando dados da slice 173000-173999
# Carregando dados da slice 317000-317999
# Carregando dados da slice 146000-146999
# Carregando dados da slice 254000-254999
# Carregando dados da slice 296000-296999
# Carregando dados da slice 73000-73999
# Carregando dados da slice 69000-69999
# Carregando dados da slice 272000-272999
# Carregando dados da slice 302000-302999
# Carregando dados da slice 209000-209999
# Carregando dados da slice 38000-38999
# Carregando dados da slice 77000-77999
# Carregando dados da slice 140000-140999
# Carregando dados da slice 200000-200999
# Carregando dados da slice 90000-90999
# Carregando dados da slice 35000-35999
# Carregando dados da slice 239000-239999
# Carregando dados da slice 175000-175999
# Carregando dados da slice 293000-293999
# Carregando dados da slice 137000-137999
# Carregando dados da slice 37000-37999
# Carregando dados da slice 214000-214999
# Carregando dados da slice 341000-341999
# Carregando dados da slice 51000-51999
# Carregando dados da slice 181000-181999
# Carregando dados da slice 282000-282999
# Carregando dados da slice 397000-397999
# Carregando dados da slice 82000-82999
# Carregando dados da slice 144000-144999
# Carregando dados da slice 0-999
# Carregando dados da slice 246000-246999
# Carregando dados da slice 293000-293999
# Carregando dados da slice 85000-85999
# Carregando dados da slice 226000-226999
# Carregando dados da slice 387000-387999
# Carregando dados da slice 163000-163999
# Carregando dados da slice 29000-29999
# Carregando dados da slice 92000-92999
# Carregando dados da slice 41000-41999
# Carregando dados da slice 40000-40999
# Carregando dados da slice 135000-135999
# Carregando dados da slice 377000-377999
# Carregando dados da slice 344000-344999
# Carregando dados da slice 27000-27999
# Carregando dados da slice 158000-158999
# Carregando dados da slice 119000-119999
# Carregando dados da slice 80000-80999
# Carregando dados da slice 368000-368999
# Carregando dados da slice 297000-297999
# Carregando dados da slice 388000-388999
# Carregando dados da slice 92000-92999
# Carregando dados da slice 376000-376999
# Carregando dados da slice 251000-251999
# Carregando dados da slice 158000-158999
# Carregando dados da slice 223000-223999
# Carregando dados da slice 318000-318999
# Carregando dados da slice 163000-163999
# Carregando dados da slice 201000-201999
# Carregando dados da slice 341000-341999
# Carregando dados da slice 286000-286999
# Carregando dados da slice 0-999
# Carregando dados da slice 211000-211999
# Carregando dados da slice 19000-19999
# Carregando dados da slice 33000-33999
# Carregando dados da slice 179000-179999
# Carregando dados da slice 109000-109999
# Carregando dados da slice 366000-366999
# Carregando dados da slice 39000-39999
# Carregando dados da slice 310000-310999
# Carregando dados da slice 283000-283999
# Carregando dados da slice 260000-260999
# Carregando dados da slice 295000-295999
# Carregando dados da slice 292000-292999
# Carregando dados da slice 20000-20999
# Carregando dados da slice 87000-87999
# Carregando dados da slice 260000-260999
# Carregando dados da slice 210000-210999
# Carregando dados da slice 334000-334999
# Carregando dados da slice 170000-170999
# Carregando dados da slice 191000-191999
# Carregando dados da slice 296000-296999
# Carregando dados da slice 165000-165999
# Carregando dados da slice 6000-6999
# Carregando dados da slice 269000-269999
# Carregando dados da slice 223000-223999
# Carregando dados da slice 289000-289999
# Carregando dados da slice 103000-103999
# Carregando dados da slice 18000-18999
# Carregando dados da slice 89000-89999
# Carregando dados da slice 380000-380999
# Carregando dados da slice 135000-135999
# Carregando dados da slice 0-999
# Carregando dados da slice 388000-388999
# Carregando dados da slice 136000-136999
# Carregando dados da slice 314000-314999
# Carregando dados da slice 376000-376999
# Carregando dados da slice 131000-131999
# Carregando dados da slice 366000-366999
# Carregando dados da slice 300000-300999
# Carregando dados da slice 327000-327999
# Carregando dados da slice 89000-89999
# Carregando dados da slice 47000-47999
# Carregando dados da slice 289000-289999
# Carregando dados da slice 171000-171999
# Carregando dados da slice 88000-88999
# Carregando dados da slice 369000-369999
# Carregando dados da slice 63000-63999
# Carregando dados da slice 157000-157999
# Carregando dados da slice 277000-277999
# Carregando dados da slice 311000-311999
# Carregando dados da slice 203000-203999
# Carregando dados da slice 206000-206999
# Carregando dados da slice 112000-112999
# Carregando dados da slice 95000-95999
# Carregando dados da slice 112000-112999
# Carregando dados da slice 246000-246999
# Carregando dados da slice 315000-315999
# Carregando dados da slice 91000-91999
# Carregando dados da slice 18000-18999
# Carregando dados da slice 147000-147999
# Carregando dados da slice 319000-319999
# Carregando dados da slice 344000-344999
# Carregando dados da slice 0-999
# Carregando dados da slice 108000-108999
# Carregando dados da slice 28000-28999
# Carregando dados da slice 341000-341999
# Carregando dados da slice 9000-9999
# Carregando dados da slice 155000-155999
# Carregando dados da slice 313000-313999
# Carregando dados da slice 271000-271999
# Carregando dados da slice 51000-51999
# Carregando dados da slice 348000-348999
# Carregando dados da slice 203000-203999
# Carregando dados da slice 113000-113999
# Carregando dados da slice 133000-133999
# Carregando dados da slice 388000-388999
# Carregando dados da slice 200000-200999
# Carregando dados da slice 324000-324999
# Carregando dados da slice 237000-237999
# Carregando dados da slice 272000-272999
# Carregando dados da slice 204000-204999
# Carregando dados da slice 386000-386999
# Carregando dados da slice 267000-267999
# Carregando dados da slice 31000-31999
# Carregando dados da slice 24000-24999
# Carregando dados da slice 382000-382999
# Carregando dados da slice 369000-369999
# Carregando dados da slice 132000-132999
# Carregando dados da slice 245000-245999
# Carregando dados da slice 277000-277999
# Carregando dados da slice 137000-137999
# Carregando dados da slice 100000-100999
# Carregando dados da slice 80000-80999
# Carregando dados da slice 0-999
# Carregando dados da slice 185000-185999
# Carregando dados da slice 156000-156999
# Carregando dados da slice 46000-46999
# Carregando dados da slice 308000-308999
# Carregando dados da slice 283000-283999
# Carregando dados da slice 176000-176999
# Carregando dados da slice 126000-126999
# Carregando dados da slice 160000-160999
# Carregando dados da slice 196000-196999
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-16d6fde97dd8> in <module>
#       1 rp = RPrecisionTracks(sparse_matrix, dataset, model3.recommend_k_large, n_playlists=100)
# ----> 2 rp.evaluate()
#
# <ipython-input-13-5be7d9de83c9> in evaluate(self)
#      35             playlist = self.dataset.read_playlist_formatted(i)
#      36             if len(playlist) >= 10:
# ---> 37                 precisions[s] = self.recommend_partial_playlist(i)
#      38                 s += 1
#      39             i += 1
#
# <ipython-input-13-5be7d9de83c9> in recommend_partial_playlist(self, index)
#      24                 self.sparse_matrix[index, i] = 0
#      25
# ---> 26         rec = self.model(csr_matrix(self.sparse_matrix), index, playlist_train)
#      27         return self.precision(rec, playlist_test)
#      28
#
# <ipython-input-9-b54bcb75b523> in recommend_k_large(self, playlists, index_playlist, formatted_playlist)
#      81     def recommend_k_large(self, playlists, index_playlist, formatted_playlist):
#      82         '''Pode-se utilizar o cluster com mais músicas, com menor erro ou as músicas que mais se repetiram'''
# ---> 83         recommended, labels, centroids = self.recommend(playlists, index_playlist, formatted_playlist)
#      84         cluster_to_rec = labels.mode().iloc[0]
#      85         return recommended[cluster_to_rec]
#
# <ipython-input-9-b54bcb75b523> in recommend(self, playlists, playlist_index, formatted_playlist)
#      17
#      18         # cria lista com n_playlists playlists mais próximas e junta elas
# ---> 19         music_playlists = [dataset.read_playlist_formatted(argsort[i]) for i in range(1, self.n_playlists+1)]
#      20         concat_playlists = pd.concat(music_playlists, ignore_index=True)
#      21         # adiciona coluna com ocorrencias de cada musica
#
# <ipython-input-9-b54bcb75b523> in <listcomp>(.0)
#      17
#      18         # cria lista com n_playlists playlists mais próximas e junta elas
# ---> 19         music_playlists = [dataset.read_playlist_formatted(argsort[i]) for i in range(1, self.n_playlists+1)]
#      20         concat_playlists = pd.concat(music_playlists, ignore_index=True)
#      21         # adiciona coluna com ocorrencias de cada musica
#
# ~/SpotifyRecommender/auxiliarScripts/dataset_reader.py in read_playlist_formatted(self, index)
#      22
#      23     def read_playlist_formatted(self, index):
# ---> 24         playlist = self.read_playlist(index)
#      25         return pd.DataFrame(playlist['tracks'])
#
# ~/SpotifyRecommender/auxiliarScripts/dataset_reader.py in read_playlist(self, index)
#      18     def read_playlist(self, index):
#      19         if not (self.current_slice*1000 <= index <= self.current_slice*1000+999):
# ---> 20             self._load_slice(index//1000)
#      21         return self.playlists[index % 1000]
#      22
#
# ~/SpotifyRecommender/auxiliarScripts/dataset_reader.py in _load_slice(self, data_slice)
#      13             print(f"Carregando dados da slice {data_slice*1000}-{data_slice*1000+999}")
#      14         with open(f'../data/mpd.slice.{data_slice*1000}-{data_slice*1000+999}.json') as f:
# ---> 15             self.playlists = json.load(f)['playlists']
#      16         self.current_slice = data_slice
#      17
#
# ~/anaconda3/lib/python3.8/json/__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#
# ~/anaconda3/lib/python3.8/codecs.py in decode(self, input, final)
#     317         raise NotImplementedError
#     318
# --> 319     def decode(self, input, final=False):
#     320         # decode input (taking the buffer into account)
#     321         data = self.buffer + input
#
# KeyboardInterrupt:
